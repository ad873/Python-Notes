# %% [markdown]
# ---
# * GENERAL PURPOSE PROGRAMMING LANGUAGE
# * GUIDO VAN ROSSAM 1989
# * 1991 : PUBLIC
# * C/JAVA : STATICALLY TYPED LANG
# * PYTHON : DYNAMICALLY TYPED LANG

# %% [markdown]
# ---
# **<CENTER>WHERE WE CAN USE PYTHON**
# ---
# * DESKTOP APPLICATIONS
# * WEB APPLICATIONS : DJANGO,FLASK
# * DATABASE APPLICATIONS
# * NETWORKING APPLICATIONS
# * GAMES
# * DATA ANALYSIS
# * MACHINE LEARNING
# * AI
# * IoT

# %% [markdown]
# ---
# **<CENTER>COMPANIES USING PYTHON**
# ---
# * GOOGLE
# * YOUTUBE
# * DROPBOX
# * NASA

# %% [markdown]
# ---
# **<CENTER>FEATURES OF PYTHON**
# ---
# * SIMPLE AND EASY TO LEARN
# * ***OPEN SOURCE*** FREEWARE
# * HIGH LEVEL PROGRAMMING LANGUAGE
# * PLATFORM INDEPENDENT
# * PORTABILITY
# * ***DYNAMICALLY TYPED***
# * BOTH ***OBJECT ORIENTED*** AND ***PROCEDURE ORIENTED***
# * ***INTERPRETED***
# * ***EXTENSIBLE***
# * ***EMBEDDED***
# * ***RICH LIBRARY SUPPORT***

# %% [markdown]
# ---
# **<CENTER>LIMITATIONS OF PYTHON**
# ---
# * PERFORMANCE
# * MOBILE APPLICATION

# %% [markdown]
# ---
# **<CENTER>FLAVOURS OF PYTHON**
# ---
# * CPYTHON
# * JYTHON or JPYTHON
# * IRONPYTHON
# * PYPY [PVM : JIT]
# * RUBYPYTHON
# * ANACONDA PYTHON
# * STACKLESS [CONCURRENCY]

# %% [markdown]
# ---
# **<CENTER>VERSIONS OF PYTHON**
# ---
# * PYTHON 1.0 JAN '94
# * PYTHON 2.0 OCT '00
# * PYTHON 3.0 DEC '08
# <BR><BR>
# NO BACKWARD COMPATIBILITY
